# %%
filename = '/srv/conda/envs/notebook/lib/python3.10/site-packages/audiolazy/lazy_analysis.py'
with open(filename) as f:
    a = f.readlines()
    
for line in a:
    if 'from collections import deque, Sequence, Iterable' in line:
        a[a.index(line)] = 'from collections.abc import Sequence, Iterable; from collections import deque\n'
with open(filename, 'w') as f:
    f.writelines(a)

# %%
filename = '/srv/conda/envs/notebook/lib/python3.10/site-packages/audiolazy/lazy_core.py'
with open(filename) as f:
    a = f.readlines()
    
for line in a:
    if 'from collections import Iterable' in line:
        a[a.index(line)] = 'from collections.abc import Iterable\n'
with open(filename, 'w') as f:
    f.writelines(a)

# %%
filename = '/srv/conda/envs/notebook/lib/python3.10/site-packages/audiolazy/lazy_stream.py'
with open(filename) as f:
    a = f.readlines()
    
for line in a:
    if 'from collections import Iterable, deque' in line:
        a[a.index(line)] = 'from collections.abc import Iterable; from collections import deque\n'
with open(filename, 'w') as f:
    f.writelines(a)

# %%
filename = '/srv/conda/envs/notebook/lib/python3.10/site-packages/audiolazy/lazy_misc.py'
with open(filename) as f:
    a = f.readlines()
    
for line in a:
    if 'from collections import deque, Iterable' in line:
        a[a.index(line)] = 'from collections.abc import Iterable; from collections import deque\n'
with open(filename, 'w') as f:
    f.writelines(a)

# %%
filename = '/srv/conda/envs/notebook/lib/python3.10/site-packages/audiolazy/lazy_filters.py'
with open(filename) as f:
    a = f.readlines()
    
for line in a:
    if 'from collections import Iterable, OrderedDict' in line:
        a[a.index(line)] = 'from collections.abc import Iterable; from collections import OrderedDict\n'
with open(filename, 'w') as f:
    f.writelines(a)

# %%
filename = '/srv/conda/envs/notebook/lib/python3.10/site-packages/audiolazy/lazy_poly.py'
with open(filename) as f:
    a = f.readlines()
    
for line in a:
    if 'from collections import Iterable, deque, OrderedDict' in line:
        a[a.index(line)] = 'from collections.abc import Iterable; from collections import deque, OrderedDict\n'
with open(filename, 'w') as f:
    f.writelines(a)

# %%
filename = '/srv/conda/envs/notebook/lib/python3.10/site-packages/audiolazy/lazy_itertools.py'
with open(filename) as f:
    a = f.readlines()
    
for line in a:
    if 'from collections import Iterator' in line:
        a[a.index(line)] = 'from collections.abc import Iterator\n'
with open(filename, 'w') as f:
    f.writelines(a)
